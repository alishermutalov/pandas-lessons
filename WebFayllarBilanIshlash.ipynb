# %% [markdown]
# <a href="https://colab.research.google.com/github/alishermutalov/pandas-lessons/blob/pandas-learning/WebFayllarBilanIshlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
tashkent = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
len(tashkent)
# Out:
# 18

# %%
df = tashkent[10]
df.columns = ["Nr", 	"District", 	"Population", "Area","Density",	"Map"]
df
# Out:
#     Nr       District  Population   Area  Density  Map
# 0    1       Bektemir       31400  17.83     1761  NaN
# 1    2      Chilanzar      260700  29.94     8707  NaN
# 2    3      Yashnobod      258800  33.70     7680  NaN
# 3    4        Mirobod      142800  17.10     8351  NaN
# 4    5  Mirzo Ulugbek      285000  35.15     8108  NaN
# 5    6        Sergeli      105700  37.36     2829  NaN
# 6    7   Shayxontoxur      348300  29.70    11727  NaN
# 7    8        Olmazor      377100  34.50    10930  NaN
# 8    9        Uchtepa      278200  24.00    11592  NaN
# 9   10     Yakkasaray      121600  14.60     8329  NaN
# 10  11      Yunusabad      352000  40.60     8670  NaN
# 11  12     Yangihayot      132800  44.20     3005  NaN

# %%
import requests
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2015-2021")
df_json = pd.DataFrame(r.json()['works'])

# %%
df_json
# Out:
#                    key                                              title  \
# 0    /works/OL2784125W                                    Learning Python
# 1   /works/OL16976951W                                       Think Python
# 2   /works/OL17795703W                          Python for bioinformatics
# 3   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 4   /works/OL15664278W                                  Head First Python
# 5   /works/OL15667639W                              Mining the Social Web
# 6   /works/OL17422847W                           Python For Data Analysis
# 7    /works/OL6045694W                               Python in a Nutshell
# 8   /works/OL23330617W                        Making music with computers
# 9   /works/OL21703042W                               Tour of Data Science
# 10  /works/OL19548251W                                Python for Everyone
# 11  /works/OL14940051W            Natural Language Processing With Python
#
# ...

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2024-12-08 12:49:42--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 172.67.172.250, 104.21.30.141, 2606:4700:3037::ac43:acfa, ...
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|172.67.172.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K  --.-KB/s    in 0.03s
#
# 2024-12-08 12:49:42 (8.81 MB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
import sqlite3 as sql
from pprint import pprint as print

# %%
db = sql.connect("chinook.db")
cursor = db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
cursor.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute("SELECT COUNT (*) FROM employees")
cursor.fetchone()
# Out:
# (8,)

# %%
cursor.execute("PRAGMA table_info(customers)")
cursor.fetchall()
# Out:
# [(0, 'CustomerId', 'INTEGER', 1, None, 1),
#  (1, 'FirstName', 'NVARCHAR(40)', 1, None, 0),
#  (2, 'LastName', 'NVARCHAR(20)', 1, None, 0),
#  (3, 'Company', 'NVARCHAR(80)', 0, None, 0),
#  (4, 'Address', 'NVARCHAR(70)', 0, None, 0),
#  (5, 'City', 'NVARCHAR(40)', 0, None, 0),
#  (6, 'State', 'NVARCHAR(40)', 0, None, 0),
#  (7, 'Country', 'NVARCHAR(40)', 0, None, 0),
#  (8, 'PostalCode', 'NVARCHAR(10)', 0, None, 0),
#  (9, 'Phone', 'NVARCHAR(24)', 0, None, 0),
#  (10, 'Fax', 'NVARCHAR(24)', 0, None, 0),
#  (11, 'Email', 'NVARCHAR(60)', 1, None, 0),
#  (12, 'SupportRepId', 'INTEGER', 0, None, 0)]

# %%
cursor.execute("SELECT * FROM customers")
customers = cursor.fetchall()

# %%
df = pd.read_sql("SELECT CustomerId, FirstName, LastName FROM customers", db, index_col='CustomerId')
df
# Out:
#             FirstName      LastName
# CustomerId
# 1                Luís     Gonçalves
# 2              Leonie        Köhler
# 3            François      Tremblay
# 4               Bjørn        Hansen
# 5           František   Wichterlová
# 6              Helena          Holý
# 7              Astrid        Gruber
# 8                Daan       Peeters
# 9                Kara       Nielsen
# 10            Eduardo       Martins
# 11          Alexandre         Rocha
# 12            Roberto       Almeida
# 13           Fernanda         Ramos
# 14               Mark       Philips
# 15           Jennifer      Peterson
# 16              Frank        Harris
# 17               Jack         Smith
# 18           Michelle        Brooks
# 19                Tim         Goyer
# 20                Dan        Miller
# 21              Kathy         Chase
# 22            Heather       Leacock
# 23               John        Gordon
# 24              Frank       Ralston
# ...
