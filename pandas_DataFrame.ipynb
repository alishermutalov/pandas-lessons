# %% [markdown]
# <a href="https://colab.research.google.com/github/alishermutalov/pandas-lessons/blob/pandas-learning/pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
data = {'Yil':[2021,2020,2019,2018], 'Aholi Soni':[33.9, 33.5, 32.9, 32.5], 'Temp':[1.54, 1.48, 1.56, 1.62]}

# %%
df = DataFrame(data)
df
# Out:
#     Yil  Aholi Soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62

# %%
df.head(2)
# Out:
#     Yil  Aholi Soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48

# %%
df.shape
# Out:
# (4, 3)
